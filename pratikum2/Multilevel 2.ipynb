# %%
class food:
   def __init__(self, name):
       self.name = name

   def street_food(self):
       print("The dessert street_food")

class dessert(food):
   def __init__(self, name, digoreng):
       super().__init__(name)
       self.digoreng = digoreng

   def sweet(self):
       print("The dessert sweet")

class pisang_goreng(dessert):
   def __init__(self, name, digoreng ,tradisional):
       super().__init__(name, digoreng)
       self.tradisional = tradisional 

   def sweet(self):
       print("The pisang_goreng is yummy")
